# %% [markdown]
# ## MCP with LangGraph

# %% [markdown]
# https://www.udemy.com/course/mcp-mastery-build-ai-apps-with-claude-langchain-and-ollama/?referralCode=31C17C306A59601B8689

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import subprocess
import sys

def ask_airbnb(query):
    """Ask Airbnb agent."""
    code = f"""
            import asyncio
            from airbnb_mcp import search
            asyncio.run(search("{query}"))
            """
    result = subprocess.run([sys.executable, "-c", code], 
                          capture_output=True, text=True)
    print(result.stdout)

# %%
ask_airbnb("Find Airbnb in San Francisco for 2 adults")
# Out:
# Loaded 2 tools
#
# Here are some top Airbnb options in San Francisco for your stay (check-in: 2025-11-09 to 2025-11-14):
#
# 1. **Victorian Home (4.81★, 226 reviews)**
#    ₹39,505 for 5 nights
#    ✅ 2 queen beds | 📍 Near downtown | 🏆 Guest favorite
#
# 2. **Private Room with Bath (5.0★, 3 reviews)**
#    ₹32,034 for 5 nights
#    ✅ 1 bedroom | 📍 27 Nov–2 Dec | 🏆 Top-rated
#
# 3. **Master King Room (4.94★, 172 reviews)**
#    ₹50,118 for 5 nights
#    ✅ 2 beds | 📍 27 Nov–2 Dec | 🏆 Guest favorite
#
# 4. **Deluxe King Room (4.95★, 629 reviews)**
#    ₹68,459 for 5 nights
#    ✅ Near Ritz-Carlton | 📍 29 Nov–4 Dec | 🏆 Top-rated
#
# 5. **Pacific Heights Suite (4.93★, 532 reviews)**
#    ₹67,169 for 5 nights
#    ✅ 2 queen beds | 📍 3–8 Dec | 🏆 Guest favorite
#
# **More options available** – use the pagination link below to explore additional listings:
# 🔗 [Next Page](https://www.airbnb.com/s/San%20Francisco/homes?adults=2&children=0&infants=0&pets=0&cursor=eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0IjoxOCwidmVyc2lvbiI6MX0=)
#
# Let me know if you'd like to filter by price, amenities, or specific dates!
